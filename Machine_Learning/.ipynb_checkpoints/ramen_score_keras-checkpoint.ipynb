# %%
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import numpy as np

# 分類対象のカテゴリ
root_dir = "F:/ramen_img100/4obj100.npy"
classes = ["class1", "class2", "class3", "class4", "class5", "class6", "class7", "class8"]
nb_classes = len(classes)
image_size = 50

# データをロード --- (※1)
def main():
    X_train, X_test, y_train, y_test = np.load(root_dir)
    # データを正規化する
    X_train = X_train.astype("float") / 256
    X_test  = X_test.astype("float")  / 256
    y_train = np_utils.to_categorical(y_train, nb_classes)
    y_test  = np_utils.to_categorical(y_test, nb_classes)
    # モデルを訓練し評価する    
    #print(X_train[1])
    model = model_train(X_train, y_train)
    model_eval(model, X_test, y_test)

# モデルを構築 --- (※2)
def build_model(in_shape):
    model = Sequential()
    model.add(Convolution2D(32, 3, 3, 
	border_mode='same',
	input_shape=in_shape))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Convolution2D(64, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, 3, 3))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten()) 
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    model.compile(loss='binary_crossentropy',
	optimizer='rmsprop',
	metrics=['accuracy'])
    
    model.summary()
    return model

# モデルを訓練する --- (※3)
def model_train(X, y):
    model = build_model(X.shape[1:])
    model.fit(X, y, batch_size=32, nb_epoch=10)
    # モデルを保存する --- (※4)
    hdf5_file = "F:/ramen_img100/ramen_model.hdf5"
    model.save_weights(hdf5_file)
    return model

# モデルを評価する --- (※5)
def model_eval(model, X, y):
    score = model.evaluate(X, y)
    print('loss=', score[0])
    print('accuracy=', score[1])

if __name__ == "__main__":
    main()
# Out:
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(50, 50, 3..., padding="same")`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:35: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 50, 50, 32)        896
# _________________________________________________________________
# activation_5 (Activation)    (None, 50, 50, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# activation_6 (Activation)    (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 23, 23, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7744)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               3965440
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 4104
# _________________________________________________________________
# activation_8 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 4,025,864.0
# Trainable params: 4,025,864.0
# Non-trainable params: 0.0
# _________________________________________________________________
# F:\.anaconda\envs\tensorflow\lib\site-packages\keras\models.py:826: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/10
# 600/600 [==============================] - 13s - loss: 0.4226 - acc: 0.8696
# Epoch 2/10
# 600/600 [==============================] - 12s - loss: 0.3787 - acc: 0.8750
# Epoch 3/10
# 600/600 [==============================] - 12s - loss: 0.3883 - acc: 0.8696
# Epoch 4/10
# 600/600 [==============================] - 12s - loss: 0.3757 - acc: 0.8750
# Epoch 5/10
# 600/600 [==============================] - 12s - loss: 0.3732 - acc: 0.8750
# Epoch 6/10
# 600/600 [==============================] - 12s - loss: 0.3677 - acc: 0.8750
# Epoch 7/10
# 600/600 [==============================] - 12s - loss: 0.3510 - acc: 0.8731
# Epoch 8/10
# 600/600 [==============================] - 12s - loss: 0.3276 - acc: 0.8787
# Epoch 9/10
# 600/600 [==============================] - 12s - loss: 0.3026 - acc: 0.8846
# Epoch 10/10
# 600/600 [==============================] - 12s - loss: 0.2480 - acc: 0.9048
# 200/200 [==============================] - 1s
# loss= 0.472655918598
# accuracy= 0.8525

# %%
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import numpy as np
from keras.callbacks import ModelCheckpoint

# 分類対象のカテゴリ
root_dir = "F:/ramen_img100/4obj100.npy"
classes = ["class1", "class2", "class3", "class4", "class5", "class6", "class7", "class8"]
nb_classes = len(classes)
image_size = 50

# データをロード --- (※1)
def main():
    X_train, X_test, y_train, y_test = np.load(root_dir)
    # データを正規化する
    X_train = X_train.astype("float") / 256
    X_test  = X_test.astype("float")  / 256
    y_train = np_utils.to_categorical(y_train, nb_classes)
    y_test  = np_utils.to_categorical(y_test, nb_classes)
    # モデルを訓練し評価する    
    #print(X_train[1])
    model = model_train(X_train, y_train)
    model_eval(model, X_test, y_test)

# モデルを構築 --- (※2)
def build_model(in_shape):
    model = Sequential()
    model.add(Convolution2D(32, 3, 3, 
	border_mode='same',
	input_shape=in_shape))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Convolution2D(64, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, 3, 3))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten()) 
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    model.compile(loss='binary_crossentropy',
	optimizer='rmsprop',
	metrics=['accuracy'])
    
    model.summary()
    return model

# モデルを訓練する --- (※3)
def model_train(X, y):
    model = build_model(X.shape[1:])
    check = ModelCheckpoint("model.hdf5")
    history = model.fit(X, y,validation_split=0.33, batch_size=32, nb_epoch=10, callbacks=[check])
    # モデルを保存する --- (※4)
    hdf5_file = "F:/ramen_img100/ramen_model.hdf5"
    model.save_weights(hdf5_file)
    plot_history(history)
    return model

# モデルを評価する --- (※5)
def model_eval(model, X, y):
    score = model.evaluate(X, y)
    print('loss=', score[0])
    print('accuracy=', score[1])    

import matplotlib.pyplot as plt

def plot_history(history):
    # 精度の履歴をプロット
    plt.plot(history.history['acc'],"o-",label="accuracy")
    plt.plot(history.history['val_acc'],"o-",label="val_acc")
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc="lower right")
    plt.show()

    # 損失の履歴をプロット
    plt.plot(history.history['loss'],"o-",label="loss",)
    plt.plot(history.history['val_loss'],"o-",label="val_loss")
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='lower right')
    plt.show()
# modelに学習させた時の変化の様子をplot

if __name__ == "__main__":
    main()
# Out:
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", input_shape=(50, 50, 3...)`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:36: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# activation_13 (Activation)   (None, 50, 50, 32)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# activation_14 (Activation)   (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 23, 23, 64)        36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 11, 11, 64)        0
# F:\.anaconda\envs\tensorflow\lib\site-packages\keras\models.py:826: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 7744)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               3965440
# _________________________________________________________________
# activation_15 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 4104
# _________________________________________________________________
# activation_16 (Activation)   (None, 8)                 0
# =================================================================
# Total params: 4,025,864.0
# Trainable params: 4,025,864.0
# Non-trainable params: 0.0
# _________________________________________________________________
# Train on 401 samples, validate on 199 samples
# Epoch 1/10
# 401/401 [==============================] - 10s - loss: 0.4493 - acc: 0.8628 - val_loss: 0.3770 - val_acc: 0.8750
# Epoch 2/10
# 401/401 [==============================] - 9s - loss: 0.3778 - acc: 0.8750 - val_loss: 0.3773 - val_acc: 0.8750
# Epoch 3/10
# 401/401 [==============================] - 9s - loss: 0.3760 - acc: 0.8750 - val_loss: 0.3794 - val_acc: 0.8750
# Epoch 4/10
# 401/401 [==============================] - 9s - loss: 0.3813 - acc: 0.8709 - val_loss: 0.3931 - val_acc: 0.8750
# Epoch 5/10
# 401/401 [==============================] - 9s - loss: 0.3706 - acc: 0.8744 - val_loss: 0.3820 - val_acc: 0.8750
# Epoch 6/10
# 401/401 [==============================] - 9s - loss: 0.3570 - acc: 0.8747 - val_loss: 0.4039 - val_acc: 0.8744
# Epoch 7/10
# 401/401 [==============================] - 9s - loss: 0.3369 - acc: 0.8762 - val_loss: 0.4020 - val_acc: 0.8731
# Epoch 8/10
# 401/401 [==============================] - 9s - loss: 0.3136 - acc: 0.8809 - val_loss: 0.4248 - val_acc: 0.8656
# Epoch 9/10
# 401/401 [==============================] - 9s - loss: 0.2776 - acc: 0.8943 - val_loss: 0.4444 - val_acc: 0.8631
# Epoch 10/10
# 401/401 [==============================] - 9s - loss: 0.2215 - acc: 0.9199 - val_loss: 0.4760 - val_acc: 0.8492
# 200/200 [==============================] - 1s
# loss= 0.517873452902
# accuracy= 0.84125

# %%
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import numpy as np
from keras.callbacks import ModelCheckpoint

# 分類対象のカテゴリ
root_dir = "F:/ramen_img100/4obj100.npy"
classes = ["class1", "class2", "class3", "class4", "class5", "class6", "class7", "class8"]
nb_classes = len(classes)
image_size = 50

# データをロード --- (※1)
def main():
    X_train, X_test, y_train, y_test = np.load(root_dir)
    # データを正規化する
    X_train = X_train.astype("float") / 256
    X_test  = X_test.astype("float")  / 256
    y_train = np_utils.to_categorical(y_train, nb_classes)
    y_test  = np_utils.to_categorical(y_test, nb_classes)
    # モデルを訓練し評価する    
    #print(X_train[1])
    model = model_train(X_train, y_train)
    model_eval(model, X_test, y_test)

# モデルを構築 --- (※2)
def build_model(in_shape):
    model = Sequential()
    model.add(Convolution2D(32, 3, 3, 
	border_mode='same',
	input_shape=in_shape))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Convolution2D(64, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, 3, 3))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten()) 
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    model.compile(loss='binary_crossentropy',
	optimizer='rmsprop',
	metrics=['accuracy'])
    
    model.summary()
    return model

# モデルを訓練する --- (※3)
def model_train(X, y):
    model = build_model(X.shape[1:])
    check = ModelCheckpoint("model.hdf5")
    history = model.fit(X, y,validation_split=0.33, batch_size=32, nb_epoch=30, callbacks=[check])
    # モデルを保存する --- (※4)
    hdf5_file = "F:/ramen_img100/ramen_model.hdf5"
    model.save_weights(hdf5_file)
    plot_history(history)
    return model

# モデルを評価する --- (※5)
def model_eval(model, X, y):
    score = model.evaluate(X, y)
    print('loss=', score[0])
    print('accuracy=', score[1])

import matplotlib.pyplot as plt

def plot_history(history):
    # 精度の履歴をプロット
    plt.plot(history.history['acc'],"o-",label="accuracy")
    plt.plot(history.history['val_acc'],"o-",label="val_acc")
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc="lower right")
    plt.show()

    # 損失の履歴をプロット
    plt.plot(history.history['loss'],"o-",label="loss",)
    plt.plot(history.history['val_loss'],"o-",label="val_loss")
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='lower right')
    plt.show()
# modelに学習させた時の変化の様子をplot

if __name__ == "__main__":
    main()
# Out:
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", input_shape=(50, 50, 3...)`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:36: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 50, 50, 32)        896
# _________________________________________________________________
# activation_5 (Activation)    (None, 50, 50, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# activation_6 (Activation)    (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 23, 23, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7744)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               3965440
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 4104
# _________________________________________________________________
# activation_8 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 4,025,864.0
# Trainable params: 4,025,864.0
# Non-trainable params: 0.0
# _________________________________________________________________
# F:\.anaconda\envs\tensorflow\lib\site-packages\keras\models.py:826: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 401 samples, validate on 199 samples
# Epoch 1/30
# 401/401 [==============================] - 10s - loss: 0.3930 - acc: 0.8725 - val_loss: 0.3835 - val_acc: 0.8750
# Epoch 2/30
# 401/401 [==============================] - 9s - loss: 0.3816 - acc: 0.8744 - val_loss: 0.3768 - val_acc: 0.8750
# Epoch 3/30
# 401/401 [==============================] - 9s - loss: 0.3750 - acc: 0.8750 - val_loss: 0.3882 - val_acc: 0.8750
# Epoch 4/30
# 401/401 [==============================] - 9s - loss: 0.3746 - acc: 0.8750 - val_loss: 0.3805 - val_acc: 0.8750
# Epoch 5/30
# 401/401 [==============================] - 9s - loss: 0.3631 - acc: 0.8750 - val_loss: 0.4252 - val_acc: 0.8423
# Epoch 6/30
# 401/401 [==============================] - 9s - loss: 0.3611 - acc: 0.8688 - val_loss: 0.3913 - val_acc: 0.8744
# Epoch 7/30
# 401/401 [==============================] - 9s - loss: 0.3227 - acc: 0.8775 - val_loss: 0.4038 - val_acc: 0.8731
# Epoch 8/30
# 401/401 [==============================] - 8s - loss: 0.2787 - acc: 0.8959 - val_loss: 0.4378 - val_acc: 0.8624
# Epoch 9/30
# 401/401 [==============================] - 8s - loss: 0.2443 - acc: 0.9074 - val_loss: 0.4636 - val_acc: 0.8612
# Epoch 10/30
# 401/401 [==============================] - 9s - loss: 0.1868 - acc: 0.9239 - val_loss: 0.4956 - val_acc: 0.8461
# Epoch 11/30
# 401/401 [==============================] - 8s - loss: 0.1466 - acc: 0.9411 - val_loss: 0.5769 - val_acc: 0.8279
# Epoch 12/30
# 401/401 [==============================] - 9s - loss: 0.1097 - acc: 0.9626 - val_loss: 0.7094 - val_acc: 0.8147
# Epoch 13/30
# 401/401 [==============================] - 9s - loss: 0.0694 - acc: 0.9782 - val_loss: 0.7123 - val_acc: 0.8116
# Epoch 14/30
# 401/401 [==============================] - 9s - loss: 0.0615 - acc: 0.9766 - val_loss: 0.8123 - val_acc: 0.8166
# Epoch 15/30
# 401/401 [==============================] - 9s - loss: 0.0676 - acc: 0.9763 - val_loss: 0.6964 - val_acc: 0.8254
# Epoch 16/30
# 401/401 [==============================] - 8s - loss: 0.0289 - acc: 0.9919 - val_loss: 0.8572 - val_acc: 0.8097
# Epoch 17/30
# 401/401 [==============================] - 8s - loss: 0.0166 - acc: 0.9959 - val_loss: 0.8702 - val_acc: 0.8021
# Epoch 18/30
# 401/401 [==============================] - 8s - loss: 0.0213 - acc: 0.9903 - val_loss: 0.9654 - val_acc: 0.8065
# Epoch 19/30
# 401/401 [==============================] - 8s - loss: 0.0282 - acc: 0.9913 - val_loss: 0.9397 - val_acc: 0.8103
# Epoch 20/30
# 401/401 [==============================] - 9s - loss: 0.0166 - acc: 0.9944 - val_loss: 0.8691 - val_acc: 0.8065
# Epoch 21/30
# 401/401 [==============================] - 8s - loss: 0.0075 - acc: 0.9984 - val_loss: 0.9766 - val_acc: 0.8034
# Epoch 22/30
# 401/401 [==============================] - 8s - loss: 0.0272 - acc: 0.9906 - val_loss: 1.1305 - val_acc: 0.8003
# Epoch 23/30
# 401/401 [==============================] - 8s - loss: 0.0193 - acc: 0.9944 - val_loss: 1.0482 - val_acc: 0.7965
# Epoch 24/30
# 401/401 [==============================] - 8s - loss: 0.0086 - acc: 0.9978 - val_loss: 1.1251 - val_acc: 0.8009
# Epoch 25/30
# 401/401 [==============================] - 8s - loss: 0.0025 - acc: 0.9994 - val_loss: 1.1504 - val_acc: 0.7896
# Epoch 26/30
# 401/401 [==============================] - 8s - loss: 0.0436 - acc: 0.9900 - val_loss: 1.1264 - val_acc: 0.7984
# Epoch 27/30
# 401/401 [==============================] - 8s - loss: 0.0059 - acc: 0.9975 - val_loss: 1.2205 - val_acc: 0.8009
# Epoch 28/30
# 401/401 [==============================] - 8s - loss: 0.0149 - acc: 0.9938 - val_loss: 1.1575 - val_acc: 0.7933
# Epoch 29/30
# 401/401 [==============================] - 8s - loss: 0.0049 - acc: 0.9988 - val_loss: 1.1432 - val_acc: 0.8034
# Epoch 30/30
# 401/401 [==============================] - 8s - loss: 0.0014 - acc: 1.0000 - val_loss: 1.2423 - val_acc: 0.7996
# loss= 1.40078707695
# accuracy= 0.785

# %%
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import numpy as np
from keras.callbacks import ModelCheckpoint

# 分類対象のカテゴリ
root_dir = "F:/ramen_img100/4obj100.npy"
classes = ["class1", "class2", "class3", "class4", "class5", "class6", "class7", "class8"]
nb_classes = len(classes)
image_size = 50

# データをロード --- (※1)
def main():
    X_train, X_test, y_train, y_test = np.load(root_dir)
    # データを正規化する
    X_train = X_train.astype("float") / 256
    X_test  = X_test.astype("float")  / 256
    y_train = np_utils.to_categorical(y_train, nb_classes)
    y_test  = np_utils.to_categorical(y_test, nb_classes)
    # モデルを訓練し評価する    
    #print(X_train[1])
    model = model_train(X_train, y_train)
    model_eval(model, X_test, y_test)

# モデルを構築 --- (※2)
def build_model(in_shape):
    model = Sequential()
    model.add(Convolution2D(32, 3, 3, 
	border_mode='same',
	input_shape=in_shape))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Convolution2D(64, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, 3, 3))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten()) 
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    model.compile(loss='binary_crossentropy',
	optimizer='rmsprop',
	metrics=['accuracy'])
    
    model.summary()
    return model

# モデルを訓練する --- (※3)
def model_train(X, y):
    model = build_model(X.shape[1:])
    check = ModelCheckpoint("model.hdf5")
    history = model.fit(X, y,validation_split=0.25, batch_size=32, nb_epoch=30, callbacks=[check])
    # モデルを保存する --- (※4)
    hdf5_file = "F:/ramen_img100/ramen_model.hdf5"
    model.save_weights(hdf5_file)
    plot_history(history)
    return model

# モデルを評価する --- (※5)
def model_eval(model, X, y):
    score = model.evaluate(X, y)
    print('loss=', score[0])
    print('accuracy=', score[1])

import matplotlib.pyplot as plt

def plot_history(history):
    # 精度の履歴をプロット
    plt.plot(history.history['acc'],"o-",label="accuracy")
    plt.plot(history.history['val_acc'],"o-",label="val_acc")
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc="lower right")
    plt.show()

    # 損失の履歴をプロット
    plt.plot(history.history['loss'],"o-",label="loss",)
    plt.plot(history.history['val_loss'],"o-",label="val_loss")
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='lower right')
    plt.show()
# modelに学習させた時の変化の様子をplot

if __name__ == "__main__":
    main()
# Out:
# Using TensorFlow backend.
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(50, 50, 3..., padding="same")`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:36: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 50, 50, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7744)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               3965440
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 4104
# _________________________________________________________________
# activation_4 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 4,025,864.0
# Trainable params: 4,025,864.0
# Non-trainable params: 0.0
# _________________________________________________________________
# F:\.anaconda\envs\tensorflow\lib\site-packages\keras\models.py:826: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 450 samples, validate on 150 samples
# Epoch 1/30
# 450/450 [==============================] - 13s - loss: 0.9966 - acc: 0.8108 - val_loss: 0.4043 - val_acc: 0.8750
# Epoch 2/30
# 450/450 [==============================] - 10s - loss: 0.3834 - acc: 0.8750 - val_loss: 0.3872 - val_acc: 0.8750
# Epoch 3/30
# 450/450 [==============================] - 10s - loss: 0.3758 - acc: 0.8750 - val_loss: 0.4056 - val_acc: 0.8750
# Epoch 4/30
# 450/450 [==============================] - 11s - loss: 0.3839 - acc: 0.8753 - val_loss: 0.3913 - val_acc: 0.8750
# Epoch 5/30
# 450/450 [==============================] - 12s - loss: 0.3865 - acc: 0.8725 - val_loss: 0.3812 - val_acc: 0.8750
# Epoch 6/30
# 450/450 [==============================] - 12s - loss: 0.3750 - acc: 0.8750 - val_loss: 0.4086 - val_acc: 0.8742
# Epoch 7/30
# 450/450 [==============================] - 11s - loss: 0.3707 - acc: 0.8733 - val_loss: 0.4070 - val_acc: 0.8750
# Epoch 8/30
# 450/450 [==============================] - 12s - loss: 0.3619 - acc: 0.8753 - val_loss: 0.5582 - val_acc: 0.8175
# Epoch 9/30
# 450/450 [==============================] - 13s - loss: 0.3552 - acc: 0.8733 - val_loss: 0.4289 - val_acc: 0.8683
# Epoch 10/30
# 450/450 [==============================] - 12s - loss: 0.3210 - acc: 0.8814 - val_loss: 0.4501 - val_acc: 0.8500
# Epoch 11/30
# 450/450 [==============================] - 13s - loss: 0.2922 - acc: 0.8842 - val_loss: 0.5723 - val_acc: 0.8275
# Epoch 12/30
# 450/450 [==============================] - 14s - loss: 0.2784 - acc: 0.8936 - val_loss: 0.5273 - val_acc: 0.8358
# Epoch 13/30
# 450/450 [==============================] - 12s - loss: 0.2223 - acc: 0.9086 - val_loss: 0.4671 - val_acc: 0.8508
# Epoch 14/30
# 450/450 [==============================] - 11s - loss: 0.1774 - acc: 0.9283 - val_loss: 0.7489 - val_acc: 0.7983
# Epoch 15/30
# 450/450 [==============================] - 13s - loss: 0.1498 - acc: 0.9389 - val_loss: 0.7445 - val_acc: 0.8158
# Epoch 16/30
# 450/450 [==============================] - 15s - loss: 0.1188 - acc: 0.9564 - val_loss: 0.6474 - val_acc: 0.8133
# Epoch 17/30
# 450/450 [==============================] - 13s - loss: 0.0804 - acc: 0.9725 - val_loss: 0.7273 - val_acc: 0.8092
# Epoch 18/30
# 450/450 [==============================] - 13s - loss: 0.0887 - acc: 0.9686 - val_loss: 0.6616 - val_acc: 0.8258
# Epoch 19/30
# 450/450 [==============================] - 14s - loss: 0.0438 - acc: 0.9844 - val_loss: 0.8892 - val_acc: 0.8067
# Epoch 20/30
# 450/450 [==============================] - 11s - loss: 0.0486 - acc: 0.9825 - val_loss: 0.7933 - val_acc: 0.8033
# Epoch 21/30
# 450/450 [==============================] - 11s - loss: 0.0323 - acc: 0.9914 - val_loss: 1.0095 - val_acc: 0.7925
# Epoch 22/30
# 450/450 [==============================] - 12s - loss: 0.0375 - acc: 0.9858 - val_loss: 0.8788 - val_acc: 0.8050
# Epoch 23/30
# 450/450 [==============================] - 10s - loss: 0.0217 - acc: 0.9922 - val_loss: 0.9463 - val_acc: 0.7992
# Epoch 24/30
# 450/450 [==============================] - 12s - loss: 0.0187 - acc: 0.9947 - val_loss: 1.1427 - val_acc: 0.7842
# Epoch 25/30
# 450/450 [==============================] - 12s - loss: 0.0171 - acc: 0.9950 - val_loss: 1.1146 - val_acc: 0.8042
# Epoch 26/30
# 450/450 [==============================] - 12s - loss: 0.0147 - acc: 0.9944 - val_loss: 1.1781 - val_acc: 0.7933
# Epoch 27/30
# 450/450 [==============================] - 10s - loss: 0.0117 - acc: 0.9961 - val_loss: 1.1288 - val_acc: 0.7917
# Epoch 28/30
# 450/450 [==============================] - 13s - loss: 0.0183 - acc: 0.9928 - val_loss: 1.2251 - val_acc: 0.8008
# Epoch 29/30
# 450/450 [==============================] - 10s - loss: 0.0210 - acc: 0.9925 - val_loss: 1.2826 - val_acc: 0.7908
# Epoch 30/30
# 450/450 [==============================] - 12s - loss: 0.0193 - acc: 0.9933 - val_loss: 1.1839 - val_acc: 0.7942
# 200/200 [==============================] - 1s
# loss= 1.33794131279
# accuracy= 0.780625

# %%
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import numpy as np
from keras.callbacks import ModelCheckpoint

# 分類対象のカテゴリ
root_dir = "F:/ramen_img100/4obj100.npy"
classes = ["class1", "class2", "class3", "class4", "class5", "class6", "class7", "class8"]
nb_classes = len(classes)
image_size = 50

# データをロード --- (※1)
def main():
    X_train, X_test, y_train, y_test = np.load(root_dir)
    # データを正規化する
    X_train = X_train.astype("float") / 256
    X_test  = X_test.astype("float")  / 256
    y_train = np_utils.to_categorical(y_train, nb_classes)
    y_test  = np_utils.to_categorical(y_test, nb_classes)
    # モデルを訓練し評価する    
    #print(X_train[1])
    model = model_train(X_train, y_train)
    model_eval(model, X_test, y_test)

# モデルを構築 --- (※2)
def build_model(in_shape):
    model = Sequential()
    model.add(Convolution2D(32, 3, 3, 
	border_mode='same',
	input_shape=in_shape))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Convolution2D(64, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, 3, 3))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten()) 
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    model.compile(loss='binary_crossentropy',
	optimizer='rmsprop',
	metrics=['accuracy'])
    
    model.summary()
    return model

# モデルを訓練する --- (※3)
def model_train(X, y):
    model = build_model(X.shape[1:])
    check = ModelCheckpoint("model.hdf5")
    history = model.fit(X, y,validation_split=0.25, batch_size=32, nb_epoch=15, callbacks=[check])
    # モデルを保存する --- (※4)
    hdf5_file = "F:/ramen_img100/ramen_model.hdf5"
    model.save_weights(hdf5_file)
    plot_history(history)
    return model

# モデルを評価する --- (※5)
def model_eval(model, X, y):
    score = model.evaluate(X, y)
    print('loss=', score[0])
    print('accuracy=', score[1])

import matplotlib.pyplot as plt

def plot_history(history):
    # 精度の履歴をプロット
    plt.plot(history.history['acc'],"o-",label="accuracy")
    plt.plot(history.history['val_acc'],"o-",label="val_acc")
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc="lower right")
    plt.show()

    # 損失の履歴をプロット
    plt.plot(history.history['loss'],"o-",label="loss",)
    plt.plot(history.history['val_loss'],"o-",label="val_loss")
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='lower right')
    plt.show()
# modelに学習させた時の変化の様子をplot

if __name__ == "__main__":
    main()
# Out:
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(50, 50, 3..., padding="same")`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:36: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 50, 50, 32)        896
# _________________________________________________________________
# activation_5 (Activation)    (None, 50, 50, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# activation_6 (Activation)    (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 23, 23, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7744)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               3965440
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 4104
# _________________________________________________________________
# activation_8 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 4,025,864.0
# Trainable params: 4,025,864.0
# Non-trainable params: 0.0
# _________________________________________________________________
# F:\.anaconda\envs\tensorflow\lib\site-packages\keras\models.py:826: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 450 samples, validate on 150 samples
# Epoch 1/15
# 450/450 [==============================] - 10s - loss: 0.4599 - acc: 0.8642 - val_loss: 0.4272 - val_acc: 0.8542
# Epoch 2/15
# 450/450 [==============================] - 9s - loss: 0.3792 - acc: 0.8739 - val_loss: 0.3852 - val_acc: 0.8750
# Epoch 3/15
# 450/450 [==============================] - 10s - loss: 0.3817 - acc: 0.8750 - val_loss: 0.3800 - val_acc: 0.8750
# Epoch 4/15
# 450/450 [==============================] - 10s - loss: 0.3765 - acc: 0.8750 - val_loss: 0.4072 - val_acc: 0.8750
# Epoch 5/15
# 450/450 [==============================] - 10s - loss: 0.3786 - acc: 0.8747 - val_loss: 0.3866 - val_acc: 0.8750
# Epoch 6/15
# 450/450 [==============================] - 10s - loss: 0.3649 - acc: 0.8750 - val_loss: 0.4251 - val_acc: 0.8667
# Epoch 7/15
# 450/450 [==============================] - 10s - loss: 0.3515 - acc: 0.8761 - val_loss: 0.4476 - val_acc: 0.8392
# Epoch 8/15
# 450/450 [==============================] - 10s - loss: 0.3356 - acc: 0.8764 - val_loss: 0.4166 - val_acc: 0.8708
# Epoch 9/15
# 450/450 [==============================] - 10s - loss: 0.2969 - acc: 0.8883 - val_loss: 0.4442 - val_acc: 0.8633
# Epoch 10/15
# 450/450 [==============================] - 10s - loss: 0.2673 - acc: 0.8989 - val_loss: 0.4888 - val_acc: 0.8458
# Epoch 11/15
# 450/450 [==============================] - 10s - loss: 0.2318 - acc: 0.9122 - val_loss: 0.5010 - val_acc: 0.8458
# Epoch 12/15
# 450/450 [==============================] - 10s - loss: 0.1930 - acc: 0.9272 - val_loss: 0.7139 - val_acc: 0.8050
# Epoch 13/15
# 450/450 [==============================] - 10s - loss: 0.1598 - acc: 0.9425 - val_loss: 0.7093 - val_acc: 0.8150
# Epoch 14/15
# 450/450 [==============================] - 10s - loss: 0.1341 - acc: 0.9489 - val_loss: 0.6242 - val_acc: 0.8200
# Epoch 15/15
# 450/450 [==============================] - 11s - loss: 0.0788 - acc: 0.9689 - val_loss: 0.8357 - val_acc: 0.7975
# loss= 0.928946475983
# accuracy= 0.791875

# %%
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import numpy as np

# 分類対象のカテゴリ
root_dir = "F:/ramen_img100/4obj100.npy"
classes = ["miso", "sio", "tonkotsu", "shouyu"]
nb_classes = len(classes)
image_size = 150

# データをロード --- (※1)
def main():
    X_train, X_test, y_train, y_test = np.load(root_dir)
    # データを正規化する
    X_train = X_train.astype("float") / 256
    X_test  = X_test.astype("float")  / 256
    y_train = np_utils.to_categorical(y_train, nb_classes)
    y_test  = np_utils.to_categorical(y_test, nb_classes)
    # モデルを訓練し評価する    
    #print(X_train[1])
    model = model_train(X_train, y_train)
    model_eval(model, X_test, y_test)

# モデルを構築 --- (※2)
def build_model(in_shape):
    model = Sequential()
    model.add(Convolution2D(32, 3, 3, 
	border_mode='same',
	input_shape=in_shape))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Convolution2D(64, 3, 3, border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, 3, 3))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten()) 
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    model.compile(loss='binary_crossentropy',
	optimizer='rmsprop',
	metrics=['accuracy'])
    
    model.summary()
    return model

# モデルを訓練する --- (※3)
def model_train(X, y):
    model = build_model(X.shape[1:])
    model.fit(X, y, batch_size=32, nb_epoch=10)
    # モデルを保存する --- (※4)
    hdf5_file = "F:/ramen_img100/ramen_model.hdf5"
    model.save_weights(hdf5_file)
    return model

# モデルを評価する --- (※5)
def model_eval(model, X, y):
    score = model.evaluate(X, y)
    print('loss=', score[0])
    print('accuracy=', score[1])

if __name__ == "__main__":
    main()
# Out:
# Using TensorFlow backend.
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(50, 50, 3..., padding="same")`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:35: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# F:\.anaconda\envs\tensorflow\lib\site-packages\ipykernel\__main__.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 50, 50, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 11, 11, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7744)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               3965440
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2052
# _________________________________________________________________
# activation_4 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 4,023,812.0
# Trainable params: 4,023,812.0
# Non-trainable params: 0.0
# _________________________________________________________________
# F:\.anaconda\envs\tensorflow\lib\site-packages\keras\models.py:826: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/10
# 1856/3000 [=================>............] - ETA: 24s - loss: 0.6912 - acc: 0.7377
